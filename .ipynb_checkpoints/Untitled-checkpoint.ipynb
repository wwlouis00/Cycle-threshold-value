# %%
import pandas as pd
df = pd.read_csv('2021_10_22_16_26_07pos.csv')
df.head()
# Out:
#        time  temp_lid  temp_well  well_1  well_2  well_3  well_4  well_5  \
# 0  16:40:56      97.6      63.46      56      65      96      99      71
# 1  16:41:26      98.3      63.46      56      65      98      99      70
# 2  16:41:57      98.3      63.56      55      64      98      99      70
# 3  16:42:25      98.5      63.46      55      64      99      99      70
# 4  16:42:56      98.5      63.46      55      64      96      98      71
#
#    well_6  well_7  well_8  well_9  well_10  well_11  well_12  well_13  \
# 0      75      86      71      49       86       66       64      104
# 1      75      86      70      48       86       65       60      104
# 2      69      85      69      49       86       65       61      104
# 3      69      85      70      49       87       65       60      103
# 4      69      85      68      48       86       64       60      104
#
#    well_14  well_15  well_16
# 0       62       83       78
# 1       61       83       77
# ...

# %%
df = df.set_index("well_2")
df.head()
# Out:
#             time  temp_lid  temp_well  well_1  well_3  well_4  well_5  well_6  \
# well_2
# 65      16:40:56      97.6      63.46      56      96      99      71      75
# 65      16:41:26      98.3      63.46      56      98      99      70      75
# 64      16:41:57      98.3      63.56      55      98      99      70      69
# 64      16:42:25      98.5      63.46      55      99      99      70      69
# 64      16:42:56      98.5      63.46      55      96      98      71      69
#
#         well_7  well_8  well_9  well_10  well_11  well_12  well_13  well_14  \
# well_2
# 65          86      71      49       86       66       64      104       62
# 65          86      70      48       86       65       60      104       61
# 64          85      69      49       86       65       61      104       61
# 64          85      70      49       87       65       60      103       67
# 64          85      68      48       86       64       60      104       61
#
# ...

# %%
df["well_2"].plot()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'well_2'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-8c5ee4ab773f> in <module>
# ----> 1 df["well_2"].plot()
#
# ...
